# %%
import webbrowser

# %%
# generate an URL
url = 'https://' + 'www.google.com'
webbrowser.open(url)
# Out:
# False

# %%
from IPython.display import Javascript

def window_open(url):
    display(Javascript('window.open("{url}");'.format(url=url)))

# %%
window_open(url)

# %%
import requests
print(requests.get('https://ipinfo.io').json())
# Out:
# {'ip': '193.61.29.146', 'hostname': 'pc-dean.dcs.bbk.ac.uk', 'city': 'London', 'region': 'England', 'country': 'GB', 'loc': '51.5085,-0.1257', 'org': 'AS786 Jisc Services Limited', 'postal': 'EC1A', 'timezone': 'Europe/London', 'readme': 'https://ipinfo.io/missingauth'}

# %%
# !wget -v --post-data "Authorization=c372e9a8-8bb0-479e-84fb-b774b926e72a&link=0256L6d8pUej4z704PXY6H2XQuZ3SCdU" http://nlp.uniroma1.it/resources/api/download -O babelnet-5.2-index.tar.bz2
# Out:
# --2022-12-03 10:31:22--  http://nlp.uniroma1.it/resources/api/download
# Resolving nlp.uniroma1.it (nlp.uniroma1.it)... 151.100.59.110
# Connecting to nlp.uniroma1.it (nlp.uniroma1.it)|151.100.59.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47468154227 (44G) [application/json]
# Saving to: ‘babelnet-5.2-index.tar.bz2’
#
# ar.bz2               14%[=>                  ]   6.40G  5.44MB/s    eta 2h 20m
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#                babe  29%[====>               ]  12.95G  6.81MB/s    eta 2h 0m
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...

# %%
# !tar -xvf /home/manni/data/babelnet-5.2-index.tar.bz2
# Out:
# BabelNet-5.2/
# BabelNet-5.2/lexicon_ODC_BY_10/
# BabelNet-5.2/lexicon_ODC_BY_10/_2.cfs
# BabelNet-5.2/lexicon_ODC_BY_10/write.lock
# BabelNet-5.2/lexicon_ODC_BY_10/_0.cfs
# BabelNet-5.2/lexicon_ODC_BY_10/_2.cfe
# BabelNet-5.2/lexicon_ODC_BY_10/_0.cfe
# BabelNet-5.2/lexicon_ODC_BY_10/_2.si
# BabelNet-5.2/lexicon_ODC_BY_10/_0.si
# BabelNet-5.2/lexicon_ODC_BY_10/_1.cfs
# BabelNet-5.2/lexicon_ODC_BY_10/_1.cfe
# BabelNet-5.2/lexicon_ODC_BY_10/_1.si
# BabelNet-5.2/lexicon_ODC_BY_10/segments_1
# BabelNet-5.2/dict_MIT/
# BabelNet-5.2/dict_MIT/_2.cfs
# BabelNet-5.2/dict_MIT/_4.cfs
# BabelNet-5.2/dict_MIT/write.lock
# BabelNet-5.2/dict_MIT/_0.cfs
# BabelNet-5.2/dict_MIT/_4.si
# BabelNet-5.2/dict_MIT/_4.cfe
# BabelNet-5.2/dict_MIT/_3.cfs
# BabelNet-5.2/dict_MIT/_2.cfe
# BabelNet-5.2/dict_MIT/_3.si
# BabelNet-5.2/dict_MIT/_0.cfe
# BabelNet-5.2/dict_MIT/_2.si
# BabelNet-5.2/dict_MIT/_3.cfe
# BabelNet-5.2/dict_MIT/_0.si
# BabelNet-5.2/dict_MIT/_1.cfs
# BabelNet-5.2/dict_MIT/_1.cfe
# ...
